# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r'C:\Users\SKY TOP\Downloads\avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
#Average price lower than 1 and the year equal 2018

df[df['AveragePrice']<=1 & (df['year']==2018)]
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 8491           1  2018-03-18          0.95     730449.69  323507.79
# 8492           2  2018-03-11          0.96     695821.13  320199.40
# 8496           6  2018-02-11          0.87     723928.38  349354.58
# 8497           7  2018-02-04          0.86     957792.07  474887.68
# 8501          11  2018-01-07          0.98     713915.80  364463.12
# ...          ...         ...           ...           ...        ...
# 9121           7  2018-02-04          0.76    1272039.80  531469.08
# 9122           8  2018-01-28          0.85     957086.16  479147.93
# 9123           9  2018-01-21          0.84    1020913.20  505263.29
# 9124          10  2018-01-14          0.90     950954.60  463945.73
# 9125          11  2018-01-07          0.88     880266.52  436282.38
#
#            4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df['year']
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 18244    2018
# 18245    2018
# 18246    2018
# 18247    2018
# 18248    2018
# Name: year, Length: 18249, dtype: int64

# %%
df[ df['AveragePrice']==1 & (df['year']==2015)]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 57              5  2015-11-22           1.0     356414.57  269799.03
# 86             34  2015-05-03           1.0     634213.10  538403.48
# 92             40  2015-03-22           1.0     479590.62  393591.03
# 103            51  2015-01-04           1.0     435021.49  364302.39
# 190            34  2015-05-03           1.0      85466.99   66880.12
# ...           ...         ...           ...           ...        ...
# 11799          21  2015-08-02           1.0     573873.00  164126.00
# 11800          22  2015-07-26           1.0     580826.00  169940.00
# 11801          23  2015-07-19           1.0     650389.00  159752.00
# 11802          24  2015-07-12           1.0     608845.00  178871.00
# 11803          25  2015-07-05           1.0     668233.00  205073.00
#
#             4225     4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df['XLarge Bags'].unique()
# Out:
# array([  0.  ,  33.33, 104.17, ..., 228.27,  12.12,  24.18])

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df['AveragePrice'].unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %%
df[df['AveragePrice']>2]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 3231            7  2016-11-06          2.07     376476.71   31206.79
# 3232            8  2016-10-30          2.07     375213.57   33564.91
# 4999            7  2016-11-06          2.07     492504.81  109080.72
# 5000            8  2016-10-30          2.20     477937.80  130025.36
# 6050           10  2017-10-22          2.06     519814.03   84590.83
# ...           ...         ...           ...           ...        ...
# 18111           6  2018-02-11          2.22      21708.65    9960.19
# 18113           8  2018-01-28          2.27      20325.75    9368.06
# 18116          11  2018-01-07          2.30      20151.24   10165.34
# 18126           9  2018-01-21          2.02      33986.68     928.10
# 18127          10  2018-01-14          2.03      36228.45    1147.33
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df[df['AveragePrice']>=3]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 13037          12  2016-10-02          3.03       3714.71    296.71   2699.80
# 14124           7  2016-11-06          3.12      19043.80   5898.49  10039.34
# 14125           8  2016-10-30          3.25      16700.94   2325.93  11142.85
# 16055          42  2017-03-12          3.05       2068.26   1043.83     77.36
# 16715          13  2017-10-01          3.00      10741.93    140.46   4331.20
# 16720          18  2017-08-27          3.04      12656.32    419.06   4851.90
# 16985          18  2017-08-27          3.00      19329.49  10517.41   7907.99
# 17428          37  2017-04-16          3.17       3018.56   1255.55     82.31
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 13037    0.00      718.20      718.20        0.00          0.0  organic  2016
# 14124    0.00     3105.97     3079.30       26.67          0.0  organic  2016
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df=df.drop('Unnamed: 0', axis =1)
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.shape
# Out:
# (18249, 11)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.isna().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# type            0
# year            0
# region          0
# dtype: int64

# %%
plt.figure(figsize=(9,6))
plt.title('distribution average price')
sns.distplot(df['AveragePrice'],color='b')
# Out:
# C:\Users\SKY TOP\AppData\Local\Temp\ipykernel_16760\3269160158.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AveragePrice'],color='b')
# <Axes: title={'center': 'distribution average price'}, xlabel='AveragePrice', ylabel='Density'>

# %%
print("number of each type :" ,df['type'].value_counts())
# Out:
# number of each type : type
# conventional    9126
# organic         9123
# Name: count, dtype: int64

# %%
print("number of region",df['region'].value_counts())
# Out:
# number of region region
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# ...

# %%
sns.countplot(x="region",data=df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
sns.countplot(x='AveragePrice',data=df)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='count'>

# %%
sns.boxplot(x='type' ,y='AveragePrice',data=df)
# Out:
# <Axes: xlabel='type', ylabel='AveragePrice'>

# %%
sns.boxplot(x='region', y='AveragePrice',data=df)
# Out:
# <Axes: xlabel='region', ylabel='AveragePrice'>

# %%
sns.boxplot(x='year', y='region',data=df)
# Out:
# <Axes: xlabel='year', ylabel='region'>

# %%
AvPrice=df.groupby('region')["AveragePrice"].mean()
AvPrice
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Columbus               1.252781
# DallasFtWorth          1.085592
# Denver                 1.218580
# Detroit                1.276095
# GrandRapids            1.505000
# GreatLakes             1.338550
# HarrisburgScranton     1.513284
# HartfordSpringfield    1.818639
# Houston                1.047929
# Indianapolis           1.313994
# Jacksonville           1.510947
# LasVegas               1.380917
# LosAngeles             1.216006
# Louisville             1.286686
# MiamiFtLauderdale      1.428491
# Midsouth               1.404763
# Nashville              1.212101
# NewOrleansMobile       1.304793
# NewYork                1.727574
# ...

# %%
high_price=AvPrice.idxmax()
high_price
# Out:
# 'HartfordSpringfield'

# %%
low_price=AvPrice.idxmin()
low_price
# Out:
# 'Houston'

# %%
result=df.groupby('type')['4770'].mean()
result
# Out:
# type
# conventional    45405.796798
# organic           266.254582
# Name: 4770, dtype: float64

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
date_result=df.groupby('region')['Total Volume'].mean()
date_result
# Out:
# region
# Albany                 4.753787e+04
# Atlanta                2.621453e+05
# BaltimoreWashington    3.985619e+05
# Boise                  4.264257e+04
# Boston                 2.877929e+05
# BuffaloRochester       6.793630e+04
# California             3.044324e+06
# Charlotte              1.051939e+05
# Chicago                3.955690e+05
# CincinnatiDayton       1.317219e+05
# Columbus               8.873776e+04
# DallasFtWorth          6.166251e+05
# Denver                 4.109542e+05
# Detroit                1.876403e+05
# GrandRapids            8.938383e+04
# GreatLakes             1.744505e+06
# HarrisburgScranton     1.236948e+05
# HartfordSpringfield    1.499128e+05
# Houston                6.010884e+05
# Indianapolis           8.953666e+04
# Jacksonville           8.517753e+04
# LasVegas               1.608784e+05
# LosAngeles             1.502653e+06
# Louisville             4.762427e+04
# MiamiFtLauderdale      2.889740e+05
# Midsouth               1.503992e+06
# ...

# %%
sns.boxplot(x='year' , y='AveragePrice', data=df)
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>
